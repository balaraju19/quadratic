# %%
a = 1
b = -3
c = 2
with open("input_single.txt", "w") as file:
    file.write(f"{a}\n")
    file.write(f"{b}\n")
    file.write(f"{c}\n")
print("File 'input_single.txt' created with values:")
print(f"a = {a}, b = {b}, c = {c}")
# Out:
# File 'input_single.txt' created with values:
# a = 1, b = -3, c = 2
